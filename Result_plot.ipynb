# %%
import matplotlib.pyplot as plt
# matplotlib inline

# 1. Books
f = plt.figure(figsize=(10, 3))
plt.errorbar(
    ["SCAN","Radar","DOMINANT","AdONE","GUIDE","CoLA","CONAD","GAD-NR","CARD","ARISE", "Ours"],  # X
    [     79.97, 42.90, 63.14, 85.66,42.04,  48.12, 70.60,59.09,  57.91, 67.56, 93.36], # Y
    yerr=[0.0000,0.0000,0.0500,2.2600,0.3400,3.8100,0.0000,2.0900, 9.7200,0.0100,2.4395], # Y-errors
    label="Books",
    fmt="ro--", # format line like for plot()
    linewidth=2	# width of plot line
    )

plt.xlabel('Algorithm', fontsize=12)
plt.ylabel('AUC (%)', fontsize=12)

plt.axhline(y=93.36, color='b', linestyle='--', linewidth=1.0)

plt.legend() #Show legend
plt.show()

f.savefig("results/dim_R8.pdf", bbox_inches='tight')


# 2. int_Cora
f = plt.figure(figsize=(10, 3))
plt.errorbar(
    ["SCAN","Radar","DOMINANT","AdONE","GUIDE","CoLA","CONAD","GAD-NR","CARD","ARISE", "Ours"],  # X
    [89.30,57.81,94.54,83.09,87.07,50.35,95.15, 95.09, 47.98, 100.00, 99.46], # Y
    yerr=[0.0000,0.0000,0.0300,0.9200,4.9100,1.8100,0.0300, 0.1600,0.0800, 0.0000, 0.3490],     # Y-errors
    label="Int_Cora",
    fmt="ro--", # format line like for plot()
    linewidth=2	# width of plot line
    )

plt.xlabel('Algorithm', fontsize=12)
plt.ylabel('AUC (%)', fontsize=12)
plt.axhline(y=99.46, color='b', linestyle='--', linewidth=1.0)

plt.legend() #Show legend
plt.show()

f.savefig("results/dim_R8.pdf", bbox_inches='tight')

# 3. Weibo
f = plt.figure(figsize=(10, 3))
plt.errorbar(
    ["SCAN","Radar","DOMINANT","AdONE","CoLA","CONAD","GAD-NR","CARD","ARISE", "Ours"],  # X
    [     47.33, 57.81, 48.65, 58.74,59.12,  39.20, 50.95, 43.76,  50.57,  94.18], # Y
    yerr=[0.0000,0.0000,0.7900,2.6200,1.5100,2.0100,0.5300,0.4900, 0.0000,0.8094], # Y-errors
    label="Weibo",
    fmt="ro--", # format line like for plot()
    linewidth=2	# width of plot line
    )

plt.xlabel('Algorithm', fontsize=12)
plt.ylabel('AUC (%)', fontsize=12)

plt.axhline(y=94.18, color='b', linestyle='--', linewidth=1.0)

plt.legend() #Show legend
plt.show()

f.savefig("results/dim_R8.pdf", bbox_inches='tight')

# 4. Reddit
f = plt.figure(figsize=(10, 3))
plt.errorbar(
    ["SCAN","Radar","DOMINANT","AdONE","CoLA","CONAD","GAD-NR","CARD","ARISE", "Ours"],  # X
    [99.03,48.36,93.76,81.57,51.21,93.49,86.89,52.00,93.15,99.68], # Y
    yerr=[0.0000,0.0000,0.0000,1.6100,0.8400,0.0200,7.0700,1.0500,0.0000,0.6439],     # Y-errors
    label="Reddit",
    fmt="ro--", # format line like for plot()
    linewidth=2	# width of plot line
    )

plt.xlabel('Algorithm', fontsize=12)
plt.ylabel('AUC (%)', fontsize=12)

plt.axhline(y=99.68, color='b', linestyle='--', linewidth=1.0)

plt.legend() #Show legend
plt.show()

f.savefig("results/dim_R8.pdf", bbox_inches='tight')


# 5. Enron
f = plt.figure(figsize=(10, 3))
plt.errorbar(
    ["SCAN","Radar","DOMINANT","AdONE","CoLA","CONAD","GAD-NR","CARD","ARISE", "Ours"],  # X
    [94.04,39.03,44.05,89.10,57.28,90.39,60.18,43.38,67.56,91.03], # Y
    yerr=[0.0000,0.0000,0.8300,2.3700,1.7400,0.0900,4.7600,4.8900,0.0100,5.8230],     # Y-errors
    label="Enron",
    fmt="ro--", # format line like for plot()
    linewidth=2	# width of plot line
    )

plt.xlabel('Algorithm', fontsize=12)
plt.ylabel('AUC (%)', fontsize=12)

plt.axhline(y=91.03, color='b', linestyle='--', linewidth=1.0)

plt.legend() #Show legend
plt.show()

f.savefig("results/dim_R8.pdf", bbox_inches='tight')

# 6. Disney
f = plt.figure(figsize=(10, 3))
plt.errorbar(
    ["SCAN","Radar","DOMINANT","AdONE","GUIDE","CoLA","CONAD","GAD-NR","CARD","ARISE", "Ours"],  # X
    [81.19,50.89,28.83,76.09,59.96,51.16,34.20,63.65,52.92,56.21,82.30], # Y
    yerr=[0.0000,0.0000,4.0200,2.7700,0.2500,4.8100,4.7400,6.7100,3.0900,0.0000,8.1890],     # Y-errors
    label="Disney",
    fmt="ro--", # format line like for plot()
    linewidth=2	# width of plot line
    )
plt.xlabel('Algorithm', fontsize=12)
plt.ylabel('AUC (%)', fontsize=12)

plt.axhline(y=82.30, color='b', linestyle='--', linewidth=1.0)

plt.legend() #Show legend
plt.show()

f.savefig("results/dim_R8.pdf", bbox_inches='tight')
